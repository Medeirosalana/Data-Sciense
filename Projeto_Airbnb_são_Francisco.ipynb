# %% [markdown]
# <a href="https://colab.research.google.com/github/Medeirosalana/Data-Sciense/blob/main/Projeto_Airbnb_s%C3%A3o_Francisco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # São Francisco, Califórnia, EUA #
#   Vamos iniciar esse projeto falando sobre os alugueis de moradias para a cidade de São Francisco na Califórnia.
#
# São Francisco é uma cidade onde muitos estudantes querem ir fazer intercambio pela sua economia, ela é a decima oitava cidade mais rica do mundo, onde está concentrado centros financeiros e o vale do silício onde foi fundada grandes marcas da tecnológica como Apple, Windows e diversos outras grandes empresas.
#
# Esses dados que mostrarei abaixo são dados do Airbnb de alugueis de casas, apartamentos e hotéis.

# %% [markdown]
# <img alt="Analisando Airbnb" width="100%" src="https://viagemeturismo.abril.com.br/wp-content/uploads/2021/07/GettyImages-985581350-1.jpg?quality=70&strip=info&resize=680,453">

# %% [markdown]
# # Obtenção dos Dados

# %% [markdown]
# Vamos iniciar nossa obtenção de dados com as importações dos
# arquivos necessários para iniciar a análise dos dados.

# %%
# Importação dos arquivos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Importação arquivo csv 
df=pd.read_csv("http://data.insideairbnb.com/united-states/ca/san-francisco/2021-12-04/visualisations/listings.csv")

# %% [markdown]
# # Análise dos dados

# %% [markdown]
# Vamos iniciar a análise dos dados obtidos do arquivo.

# %% [markdown]
# **Dicionário dos dados**
#
#
# *   `id` - Número da chave para identificar o imóvel
# *   `name`- Nome da propriedade anunciada
# *   `host_id` - Número da chave do proprietário da propriedade
# *   `host_name` - Nome do proprietário
# *   `neighbourhood_group` - Essa columa não possui nenhum valor válido
# *   `neighbourhood` - Bairro da propriedade
# *   `latitude` - Coordenada da latitude da propriedade
# *   `longitude` - Coordenada da longitude da propriedade
# *   `room_type` - Tipo de quarto ofertado
# *   `price` - Preço para alugar o imóvel
# *   `minimum_nights` - Quantidade mínina de noites para reservar
# *   `number_of_reviews` - Número de visitas que o imóvel possui
# *   `last_review` - Data da ultima visita
# *   `reviews_per_month` - Número de visitas por mês
# *   `calculated_host_listings_count` - Quantidade de imoveis do mesmo proprietario
# *   `availability_365` - Número de dias de disponilidade em 365 dias
# *   `number_of_reviews_ltm` - Número de avaliação do imóvel em 12 meses
# *   `license` - Autorização ou número de registro do imóvel
#
# Agora vamos ver as 5 primeiras entradas do arquivo.

# %%
# Mostrar as 5 primeiras entradas
df.head()
# Out:
#      id                                               name  host_id  \
# 0   958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1  5858                                 Creative Sanctuary     8904
# 2  7918         A Friendly Room - UCSF/USF - San Francisco    21994
# 3  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 4  8339                    Historic Alamo Square Victorian    24215
#
#           host_name  neighbourhood_group     neighbourhood  latitude  \
# 0             Holly                  NaN  Western Addition  37.77028
# 1  Philip And Tania                  NaN    Bernal Heights  37.74474
# 2             Aaron                  NaN    Haight Ashbury  37.76555
# 3             Aaron                  NaN    Haight Ashbury  37.76555
# 4              Rosy                  NaN  Western Addition  37.77564
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %% [markdown]
# # Quantidade de Variaveis e entradas e os tipos da variáveis

# %% [markdown]
# Vamos prosseguir e identificar a quantidade de entradas que nosso conjunto de dados possui e ver os tipos de cada coluna.

# %%
# Identificar o volume de dados
print("Entradas:\t{}".format(df.shape[0]))
print('Variáveis:\t{}\n'.format(df.shape[1]))

# Verificar as 5 primeiras entradas do dataset
display(df.dtypes)
# Out:
# Entradas:	6413
# Variáveis:	18
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# # Porcentagem de valores ausentes

# %% [markdown]
# É importante verificar os valores ausentes nas linhas para analisar se os valores nulos são significativos em relação as entradas. Visto que esses valores ausentes fazem diferença no final da análise.
#
# *   Verificamos que `neighbourhood_group` possui 100% dos dados nulos
# *   Verificamos que `license` possui quase 50% dos dados nulos
# *   Verificamos que `reviews_per_month` e `last_review` possui 20% dos dados nulos

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum()/ df.shape[0]).sort_values(ascending=False)
# Out:
# neighbourhood_group               1.000000
# license                           0.434274
# reviews_per_month                 0.208327
# last_review                       0.208327
# host_name                         0.002183
# minimum_nights                    0.000000
# number_of_reviews_ltm             0.000000
# availability_365                  0.000000
# calculated_host_listings_count    0.000000
# number_of_reviews                 0.000000
# id                                0.000000
# name                              0.000000
# room_type                         0.000000
# longitude                         0.000000
# latitude                          0.000000
# neighbourhood                     0.000000
# host_id                           0.000000
# price                             0.000000
# dtype: float64

# %% [markdown]
# # Distribuição das variáveis

# %% [markdown]
# Vamos colocar no histograma os dados dos arquivos.

# %%
# plotar o histograma das variáveis numéricas
df.hist(bins=15 , figsize=(15,10));

# %% [markdown]
# # Média de preços

# %% [markdown]
# Podemos ver que a média de preços em São Francis é de 228,63 dólares

# %%
# Media de preços dos alugueis
df.price.mean()
# Out:
# 228.6365195696242

# %% [markdown]
# # Correlação entre as variáveis

# %% [markdown]
# Vejamos agora a correlação entre as variáveis, ou seja, vamos ver entre as variáveis se tem semelhança ou relação.

# %%
# criar uma matriz de correlação
corr = df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].corr()
# mostrar a matriz de correlação
display(corr)
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.043256          -0.044250
# minimum_nights                 -0.043256        1.000000          -0.163003
# number_of_reviews              -0.044250       -0.163003           1.000000
# reviews_per_month              -0.030708       -0.107289           0.256977
# calculated_host_listings_count -0.032045        0.100149          -0.164693
# availability_365               -0.042397        0.209016          -0.038447
#
#                                 reviews_per_month  \
# price                                   -0.030708
# minimum_nights                          -0.107289
# number_of_reviews                        0.256977
# reviews_per_month                        1.000000
# calculated_host_listings_count          -0.086198
# availability_365                        -0.000607
#
#                                 calculated_host_listings_count  \
# ...

# %%
# plotar um heatmap a partir das correlações
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);

# %% [markdown]
# # Tipo de imóvel mais alugado

# %% [markdown]
# No Airbnb podemos alugar diversos tipos de imóvel como um apartamento/casas inteiras somente um quarto ou dividir com pessoas.

# %%
# mostrar a quantidade de cada tipo de imóvel disponível
df.room_type.value_counts()
# Out:
# Entire home/apt    4111
# Private room       2108
# Shared room         133
# Hotel room           61
# Name: room_type, dtype: int64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível
df.room_type.value_counts() / df.shape[0]
# Out:
# Entire home/apt    0.641042
# Private room       0.328707
# Shared room        0.020739
# Hotel room         0.009512
# Name: room_type, dtype: float64

# %% [markdown]
# # Localidade mais cara

# %% [markdown]
# Vejamos os bairros mais caro de São Francisco

# %%
# ver preços por bairros, na média
df.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
# Out:
# neighbourhood
# Financial District     754.455090
# Chinatown              373.967480
# Russian Hill           325.119048
# Presidio               300.222222
# Marina                 296.655738
# Pacific Heights        291.095890
# Castro/Upper Market    267.854167
# North Beach            266.243386
# Inner Sunset           265.349315
# Twin Peaks             264.360000
# Name: price, dtype: float64

# %% [markdown]
# Podemos ver que os bairros mais caros de São Francisco é Financial District, chinatown e Russian Hill

# %% [markdown]
# Agora com a latitude e longitude podemos ver onde fica localizado cada imóvel.

# %%
# plotar os imóveis pela latitude-longitude
df.plot(kind="scatter", x='longitude', y='latitude', alpha=0.4, c=df['price'], s=8,
              cmap=plt.get_cmap('jet'), figsize=(12,8));

# %% [markdown]
# # Media mínima de noites

# %%
# ver a média da coluna `minimum_nights``
df.minimum_nights.mean()
# Out:
# 24.007796663028223

# %% [markdown]
# A média de mínimas de noite para aluguel é de 24 noites

# %% [markdown]
# # Conclusão

# %% [markdown]
# Foi feita uma análise superficial na base de dados da Airbnb, por essa analise percebemos que São Francisco é uma cidade extremamente comercial onde as pessoas vão para ficar um tempo na cidade como podemos ver que a média mínima de noites dos anúncios é de 24 noites, também vemos que a média dos preços dos anúncios é de 228 Dólares.
#
# Essa análise de dados é uma análise resumida, para termos uma analise mais completa usamos a base de dados completa do Airbnb.
